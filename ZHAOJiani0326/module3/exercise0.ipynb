# %%
import pandas as pd

# %% [markdown]
# ### Data Collection

# %%
import requests

# URLs of the files
train_data_url = 'https://www.raphaelcousin.com/modules/module3/exercise/module3_exercise_train.csv'
test_data_url = 'https://www.raphaelcousin.com/modules/module3/exercise/module3_exercise_test.csv'

# Function to download a file
def download_file(url, file_name):
    response = requests.get(url)
    response.raise_for_status()  # Ensure we notice bad responses
    with open(file_name, 'wb') as file:
        file.write(response.content)
    print(f'Downloaded {file_name} from {url}')

# Downloading the files
download_file(train_data_url, 'module3_exercise_train.csv')
download_file(test_data_url, 'module3_exercise_test.csv')
# Out:
# Downloaded module3_exercise_train.csv from https://www.raphaelcousin.com/modules/module3/exercise/module3_exercise_train.csv
# Downloaded module3_exercise_test.csv from https://www.raphaelcousin.com/modules/module3/exercise/module3_exercise_test.csv

# %%
df_train =  pd.read_csv("module3_exercise_train.csv", sep=",", index_col='id')

# %% [markdown]
# ### Data analysis

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Dataset Overview

# %%
df_train
# Out:
#       BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageYrBlt  \
# id
# 254              2             1           4.0           1       1977.0
# 1066             1             1           5.0           1       1983.0
# 638              4             1          10.0           1       1998.0
# 799              3             1           8.0           0       1916.0
# 380              2             1           5.0           0       2005.0
# ...            ...           ...           ...         ...          ...
# 1095             4             1           7.0           0         -1.0
# 1130             3             1           6.0           0       1964.0
# 1294             3             1           7.0           1       1996.0
# 860              3             1           6.0           1       1966.0
# 1126             4             1           9.0           1       1932.0
#
#      GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# id
# ...

# %%
df_train.shape
# Out:
# (1168, 17)

# %% [markdown]
# **Insight:**
#
# The dataset contains 1168 rows and 17 columns.

# %%
print('Sample of the dataset:')
df_train.sample(10)
# Out:
# Sample of the dataset:
#       BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageYrBlt  \
# id
# 1168             2             1           6.0           1       1975.0
# 647              2             3           8.0           0         -1.0
# 476              3             1           7.0           1       1958.0
# 732              1             1           3.0           1       2004.0
# 932              2             1           6.0           0       2006.0
# 870              2             1           6.0           1       2005.0
# 1122             4             1           7.0           0       1978.0
# 335              3             1          10.0           1       2008.0
# 606              2             1           6.0           1       1981.0
# 645              4             2           8.0           0         -1.0
#
#      GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# id
# 1168        two         418         240           38              0
# ...

# %%
print('\nSummary info:')
df_train.info()
# Out:
# Summary info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1168 entries, 254 to 1126
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   BedroomAbvGr   1168 non-null   int64
#  1   KitchenAbvGr   1168 non-null   int64
#  2   TotRmsAbvGrd   1167 non-null   float64
#  3   Fireplaces     1168 non-null   int64
#  4   GarageYrBlt    1168 non-null   float64
#  5   GarageCars     1167 non-null   object
#  6   GarageArea     1168 non-null   int64
#  7   WoodDeckSF     1168 non-null   int64
#  8   OpenPorchSF    1168 non-null   int64
#  9   EnclosedPorch  1168 non-null   int64
#  10  3SsnPorch      1168 non-null   int64
#  11  ScreenPorch    1168 non-null   int64
#  12  PoolArea       1168 non-null   int64
#  13  MiscVal        1168 non-null   int64
#  14  MoSold         1168 non-null   int64
#  15  YrSold         1167 non-null   float64
#  16  SalePrice      1168 non-null   int64
# ...

# %% [markdown]
# **Insight:**
#
# - The data types are predominantly integer (int64) with 3 columns being a float (float64) and one column object.
#
# - Categorial Variables: Columns such as GarageCars, MoSold, and YrSold are categorical variables. For example, although GarageCars refers to the “number of parking spaces”, it might represent predefined categories (such as no parking space, single parking space, or double parking space) rather than continuous data, so it can be considered a categorical variable. Meanwhile, MoSold and YrSold represent discrete time points rather than continuous data.
#
# - Continuous Variable: Columns such as GarageArea are continuous variables and can be used for statistical summaries and visualizations.
#
# - Erroneous Data: The GarageYrBlt column has values of -1.0, which suggests that it should be addressed.

# %%
df_train[df_train.isnull().any(axis=1)]
# Out:
#       BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageYrBlt  \
# id
# 1189             3             1           6.0           0       1966.0
# 135              2             1           6.0           0       1981.0
# 321              2             1           NaN           1       1948.0
#
#      GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# id
# 1189        NaN         408           0            0              0
# 135         one         308           0          176              0
# 321         one         240           0          130              0
#
#       3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SalePrice
# id
# 1189          0            0         0        0      12  2008.0     109900
# 135           0            0         0        0       6     NaN     120000
# 321           0            0         0        0      11  2007.0     119200

# %% [markdown]
# **Insight:**
#
# The dataset contains 3 missing values.

# %%
print('\nSummary statistics:')
print(f'Number different values per column\n{df_train.nunique()}')
df_train.describe()
# Out:
# Summary statistics:
# Number different values per column
# BedroomAbvGr       8
# KitchenAbvGr       3
# TotRmsAbvGrd      12
# Fireplaces         4
# GarageYrBlt       98
# GarageCars         5
# GarageArea       387
# WoodDeckSF       242
# OpenPorchSF      184
# EnclosedPorch    105
# 3SsnPorch         15
# ScreenPorch       66
# PoolArea           6
# MiscVal           19
# MoSold            12
# YrSold             5
# SalePrice        571
# dtype: int64
#        BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  GarageYrBlt  \
# count   1168.000000   1168.000000   1167.000000  1168.000000  1168.000000
# mean       2.872432      1.043664      6.497858     0.607877  1867.833904
# std        0.805929      0.212653      1.618330     0.630833   454.504382
# min        0.000000      1.000000      2.000000     0.000000    -1.000000
# 25%        2.000000      1.000000      5.000000     0.000000  1957.000000
# 50%        3.000000      1.000000      6.000000     1.000000  1977.000000
# ...

# %% [markdown]
# **Insight:**
# 1. BedroomAbvGr:\
# The average number of bedrooms above grade is around 2.87, with a standard deviation of 0.81, indicating that most homes have about 2-3 bedrooms.
#
# 2. KitchenAbvGr:\
# The average number of kitchens above grade is 1.04, with a standard deviation of 0.21. Most homes have only one kitchen, though some have up to three.
#
# 3. TotRmsAbvGrd:\
# The average total room count above grade is 6.5, with a standard deviation of 1.62, indicating that most homes have 5-7 rooms. The maximum room count is 14.
#
# 4. Fireplaces:\
# The average number of fireplaces is 0.61, with a standard deviation of 0.63. This suggests most homes have one or no fireplaces, with a maximum of three fireplaces.
#
# 5. GarageYrBlt:\
# The average garage construction year is 1867.83, with a high standard deviation (454.5). There is a -1 value, which may represent missing data or no garage.
#
# 6. GarageArea:\
# The average garage area is 469 square feet, with a standard deviation of 210, showing a significant variance in garage size, with a maximum area of 1418 square feet.
#
# 7. WoodDeckSF:\
# The average wood deck area is 92 square feet, but 25% of homes lack a wood deck. The maximum area reaches 736 square feet.
#
# 8. OpenPorchSF:\
# The average open porch area is 46 square feet, though 50% of homes do not have an open porch. The maximum area is 547 square feet.
#
# 9. EnclosedPorch:\
# The average enclosed porch area is 23.6 square feet, though most homes lack an enclosed porch.
#
# 10. 3SsnPorch:\
# The average three-season porch area is 2.78 square feet, indicating only a few homes feature this type of porch.
#
# 11. ScreenPorch:\
# The average screen porch area is 15.7 square feet, with 75% of homes lacking a screen porch.
#
# 12. PoolArea:\
# The average pool area is 2.4 square feet, indicating most homes do not have a pool, though a few have larger pools (up to 648 square feet).
#
# 13. MiscVal:\
# The average value of miscellaneous features is $39.7. Some homes have up to $15,500 in miscellaneous value, though most homes have none.
#
# 14. MoSold:\
# The median sale month is June, indicating that most homes are sold during the summer.
#
# 15. YrSold:\
# Home sales are concentrated between 2006 and 2010.
#
# 16. SalePrice:\
# The average sale price is $179,163, with a standard deviation of $76,849, showing a broad price range. The interquartile range is between $130,000 and $212,250, with the highest sale price reaching $745,000.

# %%
print('\nDuplicate rows:')
df_train[df_train.duplicated()]
# Out:
# Duplicate rows:
#       BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageYrBlt  \
# id
# 1389             3             1           7.0           0       2004.0
#
#      GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# id
# 1389        two         380           0           40              0
#
#       3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SalePrice
# id
# 1389          0            0         0        0       4  2006.0     130000

# %% [markdown]
# **Insight:**
#
# A duplicate row exists in the dataset.

# %% [markdown]
# #### Distribution of Numerical Features

# %%
print('\nHistograms of numerical features:')
df_train.hist(figsize=(20, 20))
plt.tight_layout()
plt.show()
# Out:
# Histograms of numerical features:

# %% [markdown]
# **Insight:**
#
# 1. BedroomAbvGr:\
# The number of bedrooms above grade is mostly concentrated at 2 to 3, with very few houses having more than 4 bedrooms.
#
# 2. KitchenAbvGr:\
# Most houses have only 1 kitchen, with a few having 2 or 3.
#
# 3. TotRmsAbvGrd:\
# The total number of rooms above grade has a relatively wide distribution, mainly between 5 to 8 rooms, with very few houses exceeding 10 rooms.
#
# 4. Fireplaces:\
# Most houses have 0 or 1 fireplace, with a few having 2 or 3.
#
# 5. GarageYrBlt:\
# Garage construction years are concentrated in more recent years (around 2000), with some older years, and even anomalies (such as 0 or negative values).
#
# 6. GarageArea:\
# Garage area is mostly between 300 and 600 square feet, with a few houses having over 1,000 square feet.
#
# 7. WoodDeckSF:\
# Most houses have a wood deck area below 100 square feet, while some have larger decks, reaching over 500 square feet.
#
# 8. OpenPorchSF:\
#  Open porch area is also mostly below 100 square feet, with a few houses having much larger porches.
#
# 9. EnclosedPorch:\
# Most houses do not have an enclosed porch, with a few having larger enclosed porch areas.
#
# 10. 3SsnPorch:\
# Nearly all houses lack a three-season porch, with only a few houses having one.
#
# 11. ScreenPorch:\
# Most houses do not have a screen porch, with a few having areas over 200 square feet.
#
# 12. PoolArea:\
# Almost all houses lack a pool, with only a few having significant pool areas.
#
# 13. MiscVal:\
# The value of miscellaneous features is mostly 0, with a few houses having higher miscellaneous values.
#
# 14. MoSold:\
# The sale month of houses is relatively evenly distributed, with higher sales between May and August.
#
# 15. YrSold:\
# The sale years are evenly distributed from 2006 to 2010.
#
# 16. SalePrice:\
# The distribution of sale prices is right-skewed, with most house prices concentrated between $100,000 and $200,000, and a few reaching up to $700,000.

# %% [markdown]
# #### Outlier Detection

# %% [markdown]
# Remark:
# Not all variables are suitable for box plots:
# - Discrete with Limited Categories:\
# Many columns contain discrete values limited to a few specific categories, such as GarageCars (garage capacity), KitchenAbvGr (number of kitchens above grade), and Fireplaces (number of fireplaces). These columns usually have values like 0, 1, or 2, and are better represented by bar charts since box plots are more suitable for continuous data with potential outliers.
#
# - Time Point Data:\
# MoSold (month sold) and YrSold (year sold) represent time points, which are not suitable for box plots.
#
# - Mostly Zero Values:\
# Some columns, such as 3SsnPorch (three-season porch area), ScreenPorch (screen porch area), and PoolArea (pool area), have most values set to zero, with only a few non-zero values.
#
# - Low Variability:\
# Features like Fireplaces and KitchenAbvGr have a narrow range of values, making it challenging to identify meaningful outliers in a box plot.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

print('\nBox plots to check for outliers:')
numeric_cols=['BedroomAbvGr','TotRmsAbvGrd','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','PoolArea','MiscVal','SalePrice']

n_cols=2
n_rows=int(np.ceil(len(numeric_cols)/n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, n_rows*5))
fig.tight_layout(pad=4.0)

for i, col in enumerate(numeric_cols):
    row=i//n_cols
    col_pos=i%n_cols
    sns.boxplot(x=df_train[col], ax=axes[row,col_pos])
    axes[row,col_pos].set_title(f'Box plot of {col}')

if len(numeric_cols)%n_cols!=0:
    for j in range(len(numeric_cols), n_rows * n_cols):
        fig.delaxes(axes.flatten()[j])

plt.show()
# Out:
# Box plots to check for outliers:

# %% [markdown]
# **Insight:**
#
# 1. BedroomAbvGr:
# - Most houses have between 2 to 3 bedrooms.
# - Some outliers are observed, with a few houses having 5 or more bedrooms, even reaching up to 8.
#
# 2. TotRmsAbvGrd:
# - The total number of rooms is mostly between 5 to 7.
# - A few houses have more than 10 rooms, reaching up to 14, marking them as outliers.
#
# 3.  GarageArea:
# - Garage area is primarily concentrated between 400 to 600 square feet.
# - There are some outliers, with a few houses having garage areas exceeding 1000 square feet, with a maximum close to 1400 square feet.
#
# 4. WoodDeckSF:
# - Most houses have wood deck areas under 100 square feet.
# - Several outliers are present, with some houses having wood deck areas exceeding 400 square feet, reaching a maximum of nearly 700 square feet.
#
# 5. OpenPorchSF:
# - Open porch areas are mainly below 100 square feet.
# - Some outliers exist, with open porch areas exceeding 300 square feet, and a maximum surpassing 500 square feet.
#
# 6. EnclosedPorch:
# - Most houses do not have an enclosed porch (0 square feet), but those with enclosed porches show a wide range of sizes.
# - Some outliers have enclosed porch areas close to 400 square feet.
#
# 7. 3SsnPorch:
# - The vast majority of houses have no three-season porch (0 square feet), but for those that do, the area ranges from tens to several hundred square feet.
# - There are outliers, with a few houses having three-season porches over 200 square feet, reaching a maximum of close to 300 square feet.
#
# 8. PoolArea:
# - Almost all houses do not have a pool (0 square feet).
# - A few outliers exist, with some houses having pool areas close to 600 square feet.
#
# 9. MiscVal:
# - Most houses have no miscellaneous feature value (0).
# - There are some outliers, with miscellaneous feature values going as high as 15,000 dollars.
#
# 10. SalePrice:
# - House prices are mainly concentrated between 100,000 and 250,000 dollars.
# - Some exceptionally high prices are observed, with a few houses priced above 500,000 dollars, reaching up to 700,000 dollars.

# %% [markdown]
# #### Correlation Analysis

# %%
df_train.drop('GarageCars',axis=1,inplace=True)

# %%
print("\nCorrelation matrix:")
corr_matrix = df_train.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.show()
# Out:
# Correlation matrix:

# %% [markdown]
# **Insight:**
#
# 1. BedroomAbvGr
# - Positive correlation with TotRmsAbvGrd (0.68): Houses with more bedrooms tend to have more total rooms above grade.
# - Weak positive correlation with SalePrice (0.18): This suggests that houses with more bedrooms may slightly contribute to a higher sale price, but it’s not a strong indicator.
#
# 2. KitchenAbvGr
# - Positive correlation with TotRmsAbvGrd (0.52): This suggests that homes with a higher total number of rooms are more likely to have multiple kitchens.
# - Negative correlation with SalePrice (-0.18): This indicates that there is a weak inverse relationship between the number of kitchens and the garage construction year. This could imply that older homes tend to have multiple kitchens, while newer homes generally only have one.
#
# 3. TotRmsAbvGrd
# - Postive correlation with SalePrice (0.68): This indicates that homes with a higher total number of rooms above ground tend to have higher prices. This correlation reflects a direct relationship between the size of a house and its value—larger houses are generally more appealing, and therefore command higher prices.
#
# 4. Fireplaces
# - Positive correlation with TotRmsAbvGrd (0.31): This suggests that homes with a higher total number of rooms above ground are more likely to have more fireplaces.
# - Postive correlation with SalePrice (0.44): There is a stronger positive correlation of 0.44 between Fireplaces and SalePrice. This indicates that homes with more fireplaces tend to have higher prices.
#
# 5. GarageYrBlt
# - Positive correlation with GarageArea (0.57): There is a moderate positive correlation of 0.57 between GarageYrBlt and GarageArea. This suggests that homes with more recently built garages tend to have larger garage areas.
#
# 6. GarageArea
# - Positive correlation with SalePrice (0.62): There is a strong positive correlation of 0.62 between GarageArea and SalePrice. This indicates that homes with larger garage areas generally have higher sale prices.
#
# 7. WoodDeckSF
# - In the correlation matrix, the correlation coefficients between WoodDeckSF and most other variables are close to 0, indicating a weak relationship.
# - Positive correlation with SalePrice (0.31): This suggests that homes with larger wood deck areas might have higher sale prices. Although the correlation is not particularly strong, it indicates the positive impact of deck area on home value.
#
# 8. OpenPorchSF
# - OpenPorchSF has low correlation coefficients with most other variables, close to 0, indicating a weak relationship.
# - Positive correlation with SalePrice (0.32): This indicates that homes with larger open porch areas tend to have higher sale prices.
#
# 9. EnclosedPorch
# - EnclosedPorch has low correlation coefficients with other variables.
#
# 10. The remaining variables have very low correlations with others, so they will not be further discussed.

# %%
print("\nImportant correlation with 'SalePrice':")
corrs=df_train.corr().sort_values(by=['SalePrice'])['SalePrice'].iloc[:-1]

corrs_max=corrs[-4:]
corrs_min=corrs[:4]

fig,ax=plt.subplots(figsize=(5,5))
sns.barplot(x=corrs_max.index,y=corrs_max)
plt.title("Top Positive Correlations with 'SalePrice'")
fig,ax=plt.subplots(figsize=(5,5))
sns.barplot(x=corrs_min.index,y=corrs_min)
plt.title("Top Negative Correlations with 'SalePrice'")
# Out:
# Important correlation with 'SalePrice':
# Text(0.5, 1.0, "Top Negative Correlations with 'SalePrice'")

# %%
print('\nPairplot of selected features:')
selected_features=['TotRmsAbvGrd','GarageArea','EnclosedPorch','KitchenAbvGr','SalePrice']

sns.pairplot(df_train[selected_features],hue='SalePrice',palette='viridis',diag_kind='kde',
             plot_kws={'alpha': 0.6, 's': 80, 'edgecolor': 'k'},
             height=3)

plt.show()
# Out:
# Pairplot of selected features:

# %% [markdown]
# **Insights:**
#
# 1. TotRmsAbvGrd vs. SalePrice
# - Higher TotRmsAbvGrd values (indicating more rooms above ground) are generally associated with higher sale prices.
# - This can be observed from the scatter plot, where houses with a greater number of rooms above ground tend to have higher SalePrice values, indicating a positive correlation between room count and price.
#
# 2. GarageArea vs. SalePrice
# - Houses with larger GarageArea values tend to have higher SalePrice. This trend is evident from the scatter plot, where houses with larger garage areas generally correspond to higher sale prices.
#
# 3. EnclosedPorch vs. SalePrice
# - There is no clear trend between EnclosedPorch and SalePrice. Houses with enclosed porches do not show a significant increase or decrease in price.
#
# 4. KitchenAbvGr vs. SalePrice
# - The relationship between KitchenAbvGr (number of kitchens above ground) and SalePrice is weak. Most houses have only one kitchen, and there is no significant change in sale price with the number of kitchens.
# - This indicates that the number of kitchens is likely not a major factor influencing sale price, as shown by the scatter plot, where most points are concentrated around one kitchen with no notable variation in price.

# %% [markdown]
# #### Compare distribution of train and test data

# %%
X_test=pd.read_csv('module3_exercise_test.csv',sep=',',index_col='id')
X_test.drop('GarageCars',axis=1,inplace=True)

# %%
X_test.shape
# Out:
# (292, 15)

# %%
X_test.isnull().sum()
# Out:
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       1
# GarageYrBlt      0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    1
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# dtype: int64

# %%
for col in X_test.columns:
    plt.figure()

    sns.histplot(df_train[col],label='train',color='blue',kde=False,stat='density')
    sns.histplot(X_test[col],label='test',color='orange',kde=False,stat='density')

    sns.kdeplot(df_train[col],color='blue',label='train KDE',linewidth=2)
    sns.kdeplot(X_test[col],color='orange',label='test KDE',linewidth=2)

    plt.legend()
    plt.show()

# %% [markdown]
# **Insights:**
#
# The 1d density is similar from train and test data.

# %% [markdown]
# #### Automated EDA Report with Pandas Profiling

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df_train, title="Pandas Profiling Report", explorative=True)
profile.to_file("SalePriceofHouse_data_report_exercise.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
