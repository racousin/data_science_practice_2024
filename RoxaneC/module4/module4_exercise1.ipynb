# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# !pip install requests
# !pip install patool
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 2.5 MB/s eta 0:00:00
# ...

# %%
import requests

# %% [markdown]
# ## Data Collection

# %% [markdown]
# ### Files sources

# %%
# URLs of the files
train_datas_url = 'https://www.raphaelcousin.com/modules/module4/exercise/module4_exercise_train.zip'
test_data_url = 'https://www.raphaelcousin.com/modules/module4/exercise/Neighborhood_Market_data.csv'

# Function to download a file
def download_file(url, file_name):
    response = requests.get(url)
    response.raise_for_status()  # Ensure we notice bad responses
    with open(file_name, 'wb') as file:
        file.write(response.content)
    print(f'Downloaded {file_name} from {url}')

# Downloading the files
download_file(train_datas_url, 'module4_exercise_train.zip')
download_file(test_data_url, 'Neighborhood_Market_data.csv')
# Out:
# Downloaded module4_exercise_train.zip from https://www.raphaelcousin.com/modules/module4/exercise/module4_exercise_train.zip
# Downloaded Neighborhood_Market_data.csv from https://www.raphaelcousin.com/modules/module4/exercise/Neighborhood_Market_data.csv

# %%
import patoolib

patoolib.extract_archive("module4_exercise_train.zip",outdir="/content")
# Out:
# INFO patool: Extracting module4_exercise_train.zip ...
# INFO:patool:Extracting module4_exercise_train.zip ...
# INFO patool: running /usr/bin/7z x -aou -o/content -- module4_exercise_train.zip
# INFO:patool:running /usr/bin/7z x -aou -o/content -- module4_exercise_train.zip
# INFO patool: ... module4_exercise_train.zip extracted to `/content'.
# INFO:patool:... module4_exercise_train.zip extracted to `/content'.
# '/content'

# %% [markdown]
# #### CityMart

# %%
# read "CityMart_data.csv"
df_CityMart = pd.read_csv("CityMart_data.csv", sep=",", index_col='item_code')
df_CityMart
# Out:
#           store_name  mass  dimension_length  dimension_width  \
# item_code
# P0019       CityMart  2.81             26.83            38.75
# P0024       CityMart  3.30             59.23            34.99
# P0025       CityMart  2.34             22.60            16.90
# P0034       CityMart  6.54             18.59            68.72
# P0039       CityMart  9.94             57.89            88.33
# ...              ...   ...               ...              ...
# P1984       CityMart  8.24             99.78            68.06
# P1989       CityMart  5.79             71.19            92.39
# P1992       CityMart  8.64             97.57             8.58
# P1996       CityMart  9.90             66.40            75.90
# P1998       CityMart  3.78             17.19            21.02
#
#            dimension_height  days_since_last_purchase  package_volume  \
# item_code
# P0019                 24.89                       323    25877.199625
# ...

# %% [markdown]
# #### Greenfield_Grocers

# %%
# read "Greenfield_Grocers_data.csv"
df_Greenfield = pd.read_csv("Greenfield_Grocers_data.csv", header=3, sep="|", index_col='ITEM_CODE')
df_Greenfield
# Out:
#                    STORE_NAME  MASS  DIMENSION_LENGTH  DIMENSION_WIDTH  \
# ITEM_CODE
# P0006      Greenfield_Grocers  5.02             86.68            71.64
# P0014      Greenfield_Grocers  9.91             21.67            54.91
# P0016      Greenfield_Grocers  1.13             60.03            97.39
# P0021      Greenfield_Grocers  0.95             40.36            67.91
# P0028      Greenfield_Grocers  5.24             22.37            61.78
# ...                       ...   ...               ...              ...
# P1983      Greenfield_Grocers  3.13             37.39            74.87
# P1985      Greenfield_Grocers  0.66             30.04            15.77
# P1988      Greenfield_Grocers  7.28              7.34            89.94
# P1990      Greenfield_Grocers  6.71             73.91            10.24
# P1995      Greenfield_Grocers  8.42             83.07            19.07
#
#            DIMENSION_HEIGHT  DAYS_SINCE_LAST_PURCHASE  PACKAGE_VOLUME  \
# ITEM_CODE
# ...

# %%
df_Greenfield.drop(['1', 'Unnamed: 12'], axis=1, inplace=True)
df_Greenfield.columns = [col.lower() for col in df_Greenfield.columns]
df_Greenfield.rename_axis(df_Greenfield.index.name.lower(), inplace=True)
df_Greenfield
# Out:
#                    store_name  mass  dimension_length  dimension_width  \
# item_code
# P0006      Greenfield_Grocers  5.02             86.68            71.64
# P0014      Greenfield_Grocers  9.91             21.67            54.91
# P0016      Greenfield_Grocers  1.13             60.03            97.39
# P0021      Greenfield_Grocers  0.95             40.36            67.91
# P0028      Greenfield_Grocers  5.24             22.37            61.78
# ...                       ...   ...               ...              ...
# P1983      Greenfield_Grocers  3.13             37.39            74.87
# P1985      Greenfield_Grocers  0.66             30.04            15.77
# P1988      Greenfield_Grocers  7.28              7.34            89.94
# P1990      Greenfield_Grocers  6.71             73.91            10.24
# P1995      Greenfield_Grocers  8.42             83.07            19.07
#
#            dimension_height  days_since_last_purchase  package_volume  \
# item_code
# ...

# %% [markdown]
# #### Outlet_data

# %%
# !pip install openpyxl

# %%
# read "SuperSaver_Outlet_data.xlsx"
df_SuperSaver = pd.read_excel("SuperSaver_Outlet_data.xlsx", sheet_name=None)
df_SuperSaver
# Out:
# {'Quantity':     item_code  quantity_sold
#  0       P0003            198
#  1       P0007            211
#  2       P0008            200
#  3       P0009            209
#  4       P0012            186
#  ..        ...            ...
#  374     P1976            236
#  375     P1980            192
#  376     P1986            193
#  377     P1993            185
#  378     P2000            250
#
#  [379 rows x 2 columns],
#  'Info':     Unnamed: 0          item code  store name   mass  dimension length  \
#  0        P0003  SuperSaver_Outlet        2.40  50.90              8.80
#  1        P0007  SuperSaver_Outlet        9.88  43.65             48.64
#  2        P0008  SuperSaver_Outlet        1.45  36.18             10.23
#  3        P0009  SuperSaver_Outlet        6.98  48.13             45.55
#  4        P0012  SuperSaver_Outlet        7.20  23.66             65.90
#  ..         ...                ...         ...    ...               ...
# ...

# %%
df_SuperSaver = pd.merge(df_SuperSaver['Quantity'], df_SuperSaver['Info'], left_on = 'item_code' , right_on = 'Unnamed: 0')
df_SuperSaver = df_SuperSaver.drop(['Unnamed: 0', 'stock age'], axis=1)

df_SuperSaver.columns = ['item_code', 'quantity_sold', 'store_name', 'mass', 'dimension_length', 'dimension_width', 'dimension_height', 'days_since_last_purchase', 'package_volume', 'stock_age']
df_SuperSaver.set_index('item_code', inplace=True)
df_SuperSaver
# Out:
#            quantity_sold         store_name  mass  dimension_length  \
# item_code
# P0003                198  SuperSaver_Outlet  2.40             50.90
# P0007                211  SuperSaver_Outlet  9.88             43.65
# P0008                200  SuperSaver_Outlet  1.45             36.18
# P0009                209  SuperSaver_Outlet  6.98             48.13
# P0012                186  SuperSaver_Outlet  7.20             23.66
# ...                  ...                ...   ...               ...
# P1976                236  SuperSaver_Outlet  5.10             62.99
# P1980                192  SuperSaver_Outlet  4.93             74.91
# P1986                193  SuperSaver_Outlet  4.24             31.52
# P1993                185  SuperSaver_Outlet  3.21             97.68
# P2000                250  SuperSaver_Outlet  4.94             98.34
#
#            dimension_width  dimension_height  days_since_last_purchase  \
# item_code
# ...

# %% [markdown]
# #### HighStreet_Bazaar

# %%
# read 'HighStreet_Bazaar_data.json'
df_HighStreet = pd.read_json('HighStreet_Bazaar_data.json', orient='records')
df_HighStreet.set_index('item_code', inplace=True)
df_HighStreet
# Out:
#                   store_name  mass  dimension_length  dimension_width  \
# item_code
# P0001      HighStreet_Bazaar  6.11             75.46            91.62
# P0011      HighStreet_Bazaar  4.34             16.97            93.21
# P0015      HighStreet_Bazaar  1.37             58.93            11.28
# P0017      HighStreet_Bazaar  7.27             51.51            39.21
# P0020      HighStreet_Bazaar  0.89             57.50            69.84
# ...                      ...   ...               ...              ...
# P1978      HighStreet_Bazaar  6.28             72.48            47.71
# P1981      HighStreet_Bazaar  0.91             31.13            55.22
# P1982      HighStreet_Bazaar  4.65             65.72            82.01
# P1987      HighStreet_Bazaar  4.64             93.41            52.53
# P1994      HighStreet_Bazaar  5.43             11.20            56.52
#
#            dimension_height  days_since_last_purchase  package_volume  \
# item_code
# ...

# %% [markdown]
# #### Aggregate

# %%
df_Stores = pd.concat([df_CityMart, df_Greenfield, df_SuperSaver, df_HighStreet], axis=0)
df_Stores
# Out:
#                   store_name  mass  dimension_length  dimension_width  \
# item_code
# P0019               CityMart  2.81             26.83            38.75
# P0024               CityMart  3.30             59.23            34.99
# P0025               CityMart  2.34             22.60            16.90
# P0034               CityMart  6.54             18.59            68.72
# P0039               CityMart  9.94             57.89            88.33
# ...                      ...   ...               ...              ...
# P1978      HighStreet_Bazaar  6.28             72.48            47.71
# P1981      HighStreet_Bazaar  0.91             31.13            55.22
# P1982      HighStreet_Bazaar  4.65             65.72            82.01
# P1987      HighStreet_Bazaar  4.64             93.41            52.53
# P1994      HighStreet_Bazaar  5.43             11.20            56.52
#
#            dimension_height  days_since_last_purchase  package_volume  \
# item_code
# ...

# %% [markdown]
# #### Simple baseline

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, accuracy_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import numpy as np

def get_simple_baseline(data, fillna_value=-1, drop_cols=None, k_fold=5, scaler='standard', model='linear', metric='mae', target_col=None, X_data_test=None):

    data = data.copy()
    # Handle missing values
    data.fillna(fillna_value, inplace=True)
    if X_data_test is not None:
        X_data_test = X_data_test.copy()
        X_data_test.fillna(fillna_value, inplace=True)

    # Drop unwanted columns
    if drop_cols:
        data.drop(drop_cols, axis=1, inplace=True)
        if X_data_test is not None:
            X_data_test.drop(drop_cols, axis=1, inplace=True)

    # Split data into features (X) and target (y)
    y = data[target_col]
    X = data.drop(target_col, axis=1)

    # Feature scaling
    if scaler == 'standard':
        scaler = StandardScaler()
    elif scaler == 'minmax':
        scaler = MinMaxScaler()
    else:
        scaler = None

    if scaler:
        X = scaler.fit_transform(X)
        if X_data_test is not None:
            X_data_test = scaler.transform(X_data_test)

    # Initialize the model
    if model == 'linear':
        model = LinearRegression()
    elif model == 'logistic':
        model = LogisticRegression()
    elif model == 'random_forest':
        model = RandomForestClassifier()
    else:
        raise ValueError("Unsupported model type")

    # Initialize cross-validation
    kf = KFold(n_splits=k_fold, shuffle=True, random_state=42)
    scores = []

    # Train and evaluate using k-fold cross-validation
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Train the model
        model.fit(X_train, y_train)

        # Make predictions
        y_pred = model.predict(X_test)

        # Evaluate using the specified metric
        if metric == 'mae':
            score = mean_absolute_error(y_test, y_pred)
        elif metric == 'accuracy':
            score = accuracy_score(y_test, np.round(y_pred))
        else:
            raise ValueError("Unsupported metric")

        scores.append(score)

    if X_data_test is not None:
        model.fit(X, y)
        return np.mean(scores), model.predict(X_data_test)

    # Return the average score
    return np.mean(scores)

# %%
get_simple_baseline(df_Stores, fillna_value=-1, drop_cols=['store_name', 'last_modified'], k_fold=5, scaler='standard', model='linear', metric='mae', target_col='quantity_sold')
# Out:
# 45.04056766700087

# %% [markdown]
# ### API sources

# %%
def get_api(endpoint_url):
    try:
        # Make the GET request to the mock API
        response = requests.get(endpoint_url)

        if response.status_code == 200:
            data = response.json()
            print(data["message"])
            return data['data']
        else:
            print(f"Failed to retrieve volume data. Status code: {response.status_code}")

    except Exception as e:
        print(f"An error occurred: {e}")

password = get_api("https://www.raphaelcousin.com/api/exercise/auth")["password"]
prices = get_api(f"https://www.raphaelcousin.com/api/exercise/{password}/prices")
# Out:
# Authentication successful
# Volume data retrieved successfully

# %%
df_prices = pd.DataFrame.from_dict(prices, orient='index', columns=['price'])
df_prices
# Out:
#        price
# P0001  22.14
# P0002  26.91
# P0003  16.90
# P0004   7.04
# P0005  20.84
# ...      ...
# P1996  25.80
# P1997  26.05
# P1998  17.41
# P1999   7.57
# P2000  14.42
#
# [2000 rows x 1 columns]

# %% [markdown]
# #### Aggregate

# %%
df_Stores = pd.merge(df_Stores, df_prices, left_index=True, right_index=True, how='left')
df_Stores
# Out:
#                   store_name  mass  dimension_length  dimension_width  \
# item_code
# P0019               CityMart  2.81             26.83            38.75
# P0024               CityMart  3.30             59.23            34.99
# P0025               CityMart  2.34             22.60            16.90
# P0034               CityMart  6.54             18.59            68.72
# P0039               CityMart  9.94             57.89            88.33
# ...                      ...   ...               ...              ...
# P1978      HighStreet_Bazaar  6.28             72.48            47.71
# P1981      HighStreet_Bazaar  0.91             31.13            55.22
# P1982      HighStreet_Bazaar  4.65             65.72            82.01
# P1987      HighStreet_Bazaar  4.64             93.41            52.53
# P1994      HighStreet_Bazaar  5.43             11.20            56.52
#
#            dimension_height  days_since_last_purchase  package_volume  \
# item_code
# ...

# %%
get_simple_baseline(df_Stores, fillna_value=-1, drop_cols=['store_name', 'last_modified'], k_fold=5, scaler='standard', model='linear', metric='mae', target_col='quantity_sold')
# Out:
# 44.10144429622424

# %% [markdown]
# ### Scrapping sources

# %%
# !pip install selenium
# !apt-get install chromium-chromedriver # Install the correct package name
# !apt-get update # Update the package list
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# chromium-chromedriver is already the newest version (1:85.0.4183.83-0ubuntu2.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 56 not upgraded.
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time

# Set up the Selenium WebDriver (e.g., Chrome)
# driver = webdriver.Chrome()  # Make sure ChromeDriver is installed
# driver = webdriver.Firefox()
# driver = webdriver.Edge()
# driver = webdriver.Safari()


from selenium.webdriver.chrome.options import Options
# Configure Chrome options to address the DevToolsActivePort issue
options = Options()
options.add_argument("--headless")  # Run Chrome in headless mode
options.add_argument("--no-sandbox") # Bypass OS security model
options.add_argument("--disable-dev-shm-usage") # overcome limited resource problems
driver = webdriver.Chrome(options=options)


# Open the URL
url = 'https://www.raphaelcousin.com/module4/scrapable-data'
driver.get(url)

# Wait for the page to fully load (increase time if needed)
time.sleep(5)

# Get the fully rendered page source
html = driver.page_source

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Initialize lists to store scraped data
exercise_data = []

# Find both tables
tables = soup.find_all('table')

# Close the Selenium WebDriver
driver.quit()

# Scrape the second table (Exercise Data)
course_table = tables[1]
for row in course_table.find('tbody').find_all('tr'):
    cols = row.find_all('td')
    exercise_data.append({
        'item_code': cols[0].text,
        'customer_score': float(cols[1].text),
        'total_reviews': int(cols[2].text)
    })

# Convert the lists to pandas DataFrames
df_exercise = pd.DataFrame(exercise_data)
df_exercise.set_index('item_code', inplace=True)
df_exercise
# Out:
#            customer_score  total_reviews
# item_code
# P0001                 2.0            972
# P0002                 3.0            260
# P0003                 2.0            285
# P0004                 5.0            512
# P0005                 3.0             85
# ...                   ...            ...
# P1996                 5.0            512
# P1997                 2.0            989
# P1998                 2.0            440
# P1999                 4.0             37
# P2000                 4.0            701
#
# [2000 rows x 2 columns]

# %% [markdown]
# #### Aggregate

# %%
df_Stores = pd.merge(df_Stores, df_exercise, left_index=True, right_index=True, how='left')

# %%
get_simple_baseline(df_Stores, fillna_value=-1, drop_cols=['store_name', 'last_modified'], k_fold=5, scaler='standard', model='linear', metric='mae', target_col='quantity_sold')
# Out:
# 40.02769508950211

# %% [markdown]
# ### Generating Submission File

# %%
# X_test =  read  Neighborhood_Market_data

# read
df_StoreN =  pd.read_csv("Neighborhood_Market_data.csv", sep=",", index_col='item_code')
df_StoreN
# Out:
#                     store_name  mass  dimension_length  dimension_width  \
# item_code
# P0002      Neighborhood_Market  5.51             51.79            46.72
# P0004      Neighborhood_Market  3.97             84.63            39.42
# P0005      Neighborhood_Market  5.99             39.33            83.51
# P0010      Neighborhood_Market  4.10             77.43            49.56
# P0013      Neighborhood_Market  6.96             95.39            34.61
# ...                        ...   ...               ...              ...
# P1972      Neighborhood_Market  5.68             17.89            71.87
# P1977      Neighborhood_Market  1.53             84.32            64.91
# P1991      Neighborhood_Market  7.79             84.46            82.96
# P1997      Neighborhood_Market  8.91             66.50             5.79
# P1999      Neighborhood_Market  2.03             66.77            60.18
#
#            dimension_height  days_since_last_purchase  package_volume  \
# item_code
# ...

# %%
df_StoreN = pd.merge(df_StoreN, df_prices, left_index=True, right_index=True, how='left')
df_StoreN = pd.merge(df_StoreN, df_exercise, left_index=True, right_index=True, how='left')

# %%
_, x_pred = get_simple_baseline(df_Stores, fillna_value=-1, drop_cols=['store_name', 'last_modified'], k_fold=5, scaler='standard', model='linear', metric='mae', target_col='quantity_sold', X_data_test = df_StoreN)

# %%
submission = pd.DataFrame({
    'item_code': df_StoreN.index,
    'quantity_sold': x_pred
})

submission.to_csv('submission.csv', index=False, sep=',')
submission.head()
# Out:
#   item_code  quantity_sold
# 0     P0002     160.697917
# 1     P0004     244.752360
# 2     P0005     159.974462
# 3     P0010     227.499067
# 4     P0013     241.328037
